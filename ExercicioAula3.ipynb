# %% [markdown]
# <a href="https://colab.research.google.com/github/ajPRTS/aulasBase_analiseDeDados/blob/main/ExercicioAula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "ajPRTS"
# !git config --global user.email "andrigo.prates@sou.unijui.edu.br"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=ajPRTS
# user.email=andrigo.prates@sou.unijui.edu.br
# init.defaultbranch=main

# %%
# !git clone https://github.com/ajPRTS/aulasBase_analiseDeDados.git
# %cd aulasBase_analiseDeDados
# !ls
# !git status
# !git remote -v
# Out:
# Cloning into 'aulasBase_analiseDeDados'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 4), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 6.31 KiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/aulasBase_analiseDeDados
# LICENSE  maquinasDasAulas.ipynb  README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/ajPRTS/aulasBase_analiseDeDados.git (fetch)
# origin	https://github.com/ajPRTS/aulasBase_analiseDeDados.git (push)

# %%
nota1 = float(input("digite a nota 1: "))
nota2 = float(input("digite a nota 2: "))
nota3 = float(input("digite a nota 3: "))

somat = nota1 + nota2 + nota3
med = somat / 3

print(f"Sua notas são: Nota 1: {nota1}, Nota 2: {nota2}, Nota 3: {nota3}. A média delas é: {med} ")
# Out:
# digite a nota 1: 1
# digite a nota 2: 1
# digite a nota 3: 1
# Sua notas são: Nota 1: 1.0, Nota 2: 1.0, Nota 3: 1.0. A média delas é: 1.0

# %%
# !git add .

# %%
# !git commit -m "Exercicio em Analise de Dados"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 0DEB-22F9
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as ajPRTS
# github.com
#   ✓ Logged in to github.com account ajPRTS (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'
